# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhyasivasankari/AI-Powered-Workforce-Analytics-Talent-Intelligence-Dashboard/blob/main/python/01_Data_Loading_and_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'Employee_ID': [101, 102, 103, 104, 105],
    'Employee_Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Department': ['HR', 'IT', 'Finance', 'IT', 'HR'],
    'Gender': ['Female', 'Male', 'Male', 'Male', 'Female'],
    'Age': [25, 30, 28, 35, 29],
    'Salary': [40000, 55000, 50000, 65000, 45000],
    'Performance_Rating': [4, 5, 3, 4, 5]
}

df = pd.DataFrame(data)

print(df)

# %%
display(df.head())

# %%
df.info()

# %%
display(df.describe())
