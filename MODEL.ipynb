# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhyasivasankari/AI-Powered-Workforce-Analytics-Talent-Intelligence-Dashboard/blob/main/MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

num_rows = 10

data = {
    'TrainingID': np.arange(1001, 1001 + num_rows),
    'EmployeeID': np.random.randint(101, 120, num_rows),
    'CourseName': np.random.choice(
        ['Python', 'SQL', 'Power BI', 'Machine Learning', 'Excel'],
        num_rows
    ),
    'Trainer': np.random.choice(
        ['Anita', 'Ramesh', 'Suresh', 'Kavya'],
        num_rows
    ),
    'TrainingHours': np.random.randint(5, 40, num_rows),
    'CompletionStatus': np.random.choice(
        ['Completed', 'In Progress', 'Not Started'],
        num_rows
    ),
    'Score': np.random.randint(50, 100, num_rows),
    'Certificate': np.random.choice(
        ['Yes', 'No'],
        num_rows
    ),
    'TrainingMode': np.random.choice(
        ['Online', 'Offline'],
        num_rows
    ),
    'FeedbackRating': np.random.randint(1, 6, num_rows)
}

df = pd.DataFrame(data)

print(df)
# Out:
#    TrainingID  EmployeeID        CourseName Trainer  TrainingHours  \
# 0        1001         110          Power BI  Suresh             36
# 1        1002         107            Python  Suresh             23
# 2        1003         117  Machine Learning   Anita             27
# 3        1004         117  Machine Learning  Suresh             21
# 4        1005         112             Excel  Ramesh             15
# 5        1006         110               SQL  Suresh             32
# 6        1007         112             Excel   Anita             20
# 7        1008         113               SQL  Suresh             23
# 8        1009         102               SQL   Kavya             29
# 9        1010         110            Python   Anita             27
#
#   CompletionStatus  Score Certificate TrainingMode  FeedbackRating
# 0      In Progress     62         Yes      Offline               1
# 1      Not Started     87          No       Online               1
# 2      Not Started     96         Yes       Online               5
# 3      In Progress     73          No       Online               5
# 4        Completed     98          No      Offline               5
# 5      In Progress     91         Yes       Online               1
# 6        Completed     76         Yes      Offline               1
# 7      Not Started     81         Yes      Offline               4
# 8      Not Started     55         Yes      Offline               3
# 9      Not Started     96          No      Offline               4
